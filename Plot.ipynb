# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_graph(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5, xlabel, ylabel, title= "default"):
    
    plt.plot(x1, y1, label = "heuristic 1")
    plt.plot(x2, y2, label = "heuristic 2")
    plt.plot(x3, y3, label = "heuristic 3")
    plt.plot(x4, y4, label = "heuristic 4")
    plt.plot(x5, y5, label = "heuristic 5")
 
    # naming the x axis
    plt.xlabel(xlabel)
    
    # naming the y axis
    plt.ylabel(ylabel)
 
    # giving a title to the graph
    plt.title(title)
 
    plt.legend()
    
    # displaying the plot
    plt.show()

# %%
min_val=1e9
max_val=-1

def normalize_arr(arr):
    arr_np = np.array(arr)

    if min_val == max_val:
        return arr
    # Normalize the array values between 0 and 1
    normalized_arr = (arr_np - min_val) / (max_val - min_val)
    return normalized_arr

# %%
x1, x2, x3, x4, x5 = [], [], [], [], []
y1, y2, y3, y4, y5 = [], [], [], [], []
a1, a2, a3, a4, a5 = [], [], [], [], []
b1, b2, b3, b4, b5 = [], [], [], [], []
w1=1
w2=1
w3=1
with open("output.csv", "r") as file:
    index = 0
    for line in file:
        # Split the line by comma and convert the values to floats
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            plot_graph(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5, "Number of machines", "Fraction of jobs failed due to deadline")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0])
            y1.append(values[1])
        elif index==1 :
            x2.append(values[0])
            y2.append(values[1])
        elif index==2 :
            x3.append(values[0])
            y3.append(values[1])
        elif index==3 :
            x4.append(values[0])
            y4.append(values[1])
        else :
            x5.append(values[0])
            y5.append(values[1])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            plot_graph(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5, "K", "Fraction of jobs failed due to deadline")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0])
            y1.append(values[1])
        elif index==1 :
            x2.append(values[0])
            y2.append(values[1])
        elif index==2 :
            x3.append(values[0])
            y3.append(values[1])
        elif index==3 :
            x4.append(values[0])
            y4.append(values[1])
        else :
            x5.append(values[0])
            y5.append(values[1])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            plot_graph(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5, "failure probability", "NUmber of jobs failed while executing")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0]/1000.0)
            y1.append(values[1])
        elif index==1 :
            x2.append(values[0]/1000.0)
            y2.append(values[1])
        elif index==2 :
            x3.append(values[0]/1000.0)
            y3.append(values[1])
        elif index==3 :
            x4.append(values[0]/1000.0)
            y4.append(values[1])
        else :
            x5.append(values[0]/1000.0)
            y5.append(values[1])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            plot_graph(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5, "failure probability", "NUmber of jobs failed due to reliability")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0]/1000.0)
            y1.append(values[1])
        elif index==1 :
            x2.append(values[0]/1000.0)
            y2.append(values[1])
        elif index==2 :
            x3.append(values[0]/1000.0)
            y3.append(values[1])
        elif index==3 :
            x4.append(values[0]/1000.0)
            y4.append(values[1])
        else :
            x5.append(values[0]/1000.0)
            y5.append(values[1])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            plot_graph(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5, "Number of tasks per user", "Fraction of jobs failed due to deadline")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0])
            y1.append(values[1])
        elif index==1 :
            x2.append(values[0])
            y2.append(values[1])
        elif index==2 :
            x3.append(values[0])
            y3.append(values[1])
        elif index==3 :
            x4.append(values[0])
            y4.append(values[1])
        else :
            x5.append(values[0])
            y5.append(values[1])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            plot_graph(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5, "Number of users", "Fraction of jobs failed due to deadline")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0])
            y1.append(values[1])
        elif index==1 :
            x2.append(values[0])
            y2.append(values[1])
        elif index==2 :
            x3.append(values[0])
            y3.append(values[1])
        elif index==3 :
            x4.append(values[0])
            y4.append(values[1])
        else :
            x5.append(values[0])
            y5.append(values[1])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            min_val = min(np.min(y1),np.min(y2),np.min(y3),np.min(y4),np.min(y5))
            min_val = min(min_val,np.min(a1),np.min(a2),np.min(a3),np.min(a4),np.min(a5))
            min_val = min(min_val,np.min(b1),np.min(b2),np.min(b3),np.min(b4),np.min(b5))
            max_val = max(np.max(y1),np.max(y2),np.max(y3),np.max(y4),np.max(y5))
            max_val = max(max_val,np.max(a1),np.max(a2),np.max(a3),np.max(a4),np.max(a5))
            max_val = max(max_val,np.max(b1),np.max(b2),np.max(b3),np.max(b4),np.max(b5))
            f1 = w1*normalize_arr(y1) + w2*normalize_arr(a1) + w3*normalize_arr(b1)
            f2 = w1*normalize_arr(y2) + w2*normalize_arr(a2) + w3*normalize_arr(b2)
            f3 = w1*normalize_arr(y3) + w2*normalize_arr(a3) + w3*normalize_arr(b3)
            f4 = w1*normalize_arr(y4) + w2*normalize_arr(a4) + w3*normalize_arr(b4)
            f5 = w1*normalize_arr(y5) + w2*normalize_arr(a5) + w3*normalize_arr(b5)
            plot_graph(x1, x2, x3, x4, x5, f1.tolist(), f2.tolist(), f3.tolist(), f4.tolist(), f5.tolist(), "Number of machines", "Total Cost")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            a1, a2, a3, a4, a5 = [], [], [], [], []
            b1, b2, b3, b4, b5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0])
            y1.append(values[1])
            a1.append(values[2])
            b1.append(values[3])
        elif index==1 :
            x2.append(values[0])
            y2.append(values[1])
            a2.append(values[2])
            b2.append(values[3])
        elif index==2 :
            x3.append(values[0])
            y3.append(values[1])
            a3.append(values[2])
            b3.append(values[3])
        elif index==3 :
            x4.append(values[0])
            y4.append(values[1])
            a4.append(values[2])
            b4.append(values[3])
        else :
            x5.append(values[0])
            y5.append(values[1])
            a5.append(values[2])
            b5.append(values[3])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            min_val = min(np.min(y1),np.min(y2),np.min(y3),np.min(y4),np.min(y5))
            min_val = min(min_val,np.min(a1),np.min(a2),np.min(a3),np.min(a4),np.min(a5))
            min_val = min(min_val,np.min(b1),np.min(b2),np.min(b3),np.min(b4),np.min(b5))
            max_val = max(np.max(y1),np.max(y2),np.max(y3),np.max(y4),np.max(y5))
            max_val = max(max_val,np.max(a1),np.max(a2),np.max(a3),np.max(a4),np.max(a5))
            max_val = max(max_val,np.max(b1),np.max(b2),np.max(b3),np.max(b4),np.max(b5))
            f1 = w1*normalize_arr(y1) + w2*normalize_arr(a1) + w3*normalize_arr(b1)
            f2 = w1*normalize_arr(y2) + w2*normalize_arr(a2) + w3*normalize_arr(b2)
            f3 = w1*normalize_arr(y3) + w2*normalize_arr(a3) + w3*normalize_arr(b3)
            f4 = w1*normalize_arr(y4) + w2*normalize_arr(a4) + w3*normalize_arr(b4)
            f5 = w1*normalize_arr(y5) + w2*normalize_arr(a5) + w3*normalize_arr(b5)
            plot_graph(x1, x2, x3, x4, x5, f1, f2.tolist(), f3.tolist(), f4.tolist(), f5.tolist(), "Number of Users", "Total Cost")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            a1, a2, a3, a4, a5 = [], [], [], [], []
            b1, b2, b3, b4, b5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0])
            y1.append(values[1])
            a1.append(values[2])
            b1.append(values[3])
        elif index==1 :
            x2.append(values[0])
            y2.append(values[1])
            a2.append(values[2])
            b2.append(values[3])
        elif index==2 :
            x3.append(values[0])
            y3.append(values[1])
            a3.append(values[2])
            b3.append(values[3])
        elif index==3 :
            x4.append(values[0])
            y4.append(values[1])
            a4.append(values[2])
            b4.append(values[3])
        else :
            x5.append(values[0])
            y5.append(values[1])
            a5.append(values[2])
            b5.append(values[3])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            min_val = min(np.min(y1),np.min(y2),np.min(y3),np.min(y4),np.min(y5))
            min_val = min(min_val,np.min(a1),np.min(a2),np.min(a3),np.min(a4),np.min(a5))
            min_val = min(min_val,np.min(b1),np.min(b2),np.min(b3),np.min(b4),np.min(b5))
            max_val = max(np.max(y1),np.max(y2),np.max(y3),np.max(y4),np.max(y5))
            max_val = max(max_val,np.max(a1),np.max(a2),np.max(a3),np.max(a4),np.max(a5))
            max_val = max(max_val,np.max(b1),np.max(b2),np.max(b3),np.max(b4),np.max(b5))
            f1 = w1*normalize_arr(y1) + w2*normalize_arr(a1) + w3*normalize_arr(b1)
            f2 = w1*normalize_arr(y2) + w2*normalize_arr(a2) + w3*normalize_arr(b2)
            f3 = w1*normalize_arr(y3) + w2*normalize_arr(a3) + w3*normalize_arr(b3)
            f4 = w1*normalize_arr(y4) + w2*normalize_arr(a4) + w3*normalize_arr(b4)
            f5 = w1*normalize_arr(y5) + w2*normalize_arr(a5) + w3*normalize_arr(b5)
            plot_graph(x1, x2, x3, x4, x5, f1.tolist(), f2.tolist(), f3.tolist(), f4.tolist(), f5.tolist(), "Number of Tasks per User", "Total Cost")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            a1, a2, a3, a4, a5 = [], [], [], [], []
            b1, b2, b3, b4, b5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0])
            y1.append(values[1])
            a1.append(values[2])
            b1.append(values[3])
        elif index==1 :
            x2.append(values[0])
            y2.append(values[1])
            a2.append(values[2])
            b2.append(values[3])
        elif index==2 :
            x3.append(values[0])
            y3.append(values[1])
            a3.append(values[2])
            b3.append(values[3])
        elif index==3 :
            x4.append(values[0])
            y4.append(values[1])
            a4.append(values[2])
            b4.append(values[3])
        else :
            x5.append(values[0])
            y5.append(values[1])
            a5.append(values[2])
            b5.append(values[3])
        index = (index + 1)%5
    for line in file:
        values = [float(val.strip()) for val in line.split(',')]
        if values[0] == -1:
            min_val = min(np.min(y1),np.min(y2),np.min(y3),np.min(y4),np.min(y5))
            min_val = min(min_val,np.min(a1),np.min(a2),np.min(a3),np.min(a4),np.min(a5))
            min_val = min(min_val,np.min(b1),np.min(b2),np.min(b3),np.min(b4),np.min(b5))
            max_val = max(np.max(y1),np.max(y2),np.max(y3),np.max(y4),np.max(y5))
            max_val = max(max_val,np.max(a1),np.max(a2),np.max(a3),np.max(a4),np.max(a5))
            max_val = max(max_val,np.max(b1),np.max(b2),np.max(b3),np.max(b4),np.max(b5))
            f1 = w1*normalize_arr(y1) + w2*normalize_arr(a1) + w3*normalize_arr(b1)
            f2 = w1*normalize_arr(y2) + w2*normalize_arr(a2) + w3*normalize_arr(b2)
            f3 = w1*normalize_arr(y3) + w2*normalize_arr(a3) + w3*normalize_arr(b3)
            f4 = w1*normalize_arr(y4) + w2*normalize_arr(a4) + w3*normalize_arr(b4)
            f5 = w1*normalize_arr(y5) + w2*normalize_arr(a5) + w3*normalize_arr(b5)
            plot_graph(x1, x2, x3, x4, x5, f1.tolist(), f2.tolist(), f3.tolist(), f4.tolist(), f5.tolist(), "K", "Total Cost")
            x1, x2, x3, x4, x5 = [], [], [], [], []
            y1, y2, y3, y4, y5 = [], [], [], [], []
            a1, a2, a3, a4, a5 = [], [], [], [], []
            b1, b2, b3, b4, b5 = [], [], [], [], []
            break
        if index==0 :
            x1.append(values[0])
            y1.append(values[1])
            a1.append(values[2])
            b1.append(values[3])
        elif index==1 :
            x2.append(values[0])
            y2.append(values[1])
            a2.append(values[2])
            b2.append(values[3])
        elif index==2 :
            x3.append(values[0])
            y3.append(values[1])
            a3.append(values[2])
            b3.append(values[3])
        elif index==3 :
            x4.append(values[0])
            y4.append(values[1])
            a4.append(values[2])
            b4.append(values[3])
        else :
            x5.append(values[0])
            y5.append(values[1])
            a5.append(values[2])
            b5.append(values[3])
        index = (index + 1)%5
